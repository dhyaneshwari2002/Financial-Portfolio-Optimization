# %% [markdown]
# <h2>Financial Portfolio Optimization</h2>

# %%
pip install numpy pandas yfinance matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\dhyaneshwari\anaconda3\lib\site-packages (1.26.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\dhyaneshwari\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: yfinance in c:\users\dhyaneshwari\anaconda3\lib\site-packages (0.2.61)
# Requirement already satisfied: matplotlib in c:\users\dhyaneshwari\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: requests>=2.31 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (0.11.2)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\dhyaneshwari\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Stocks list
stocks = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'TSLA']

# Download stock data with group_by='ticker' to get simpler structure
data = yf.download(stocks, start='2020-01-01', group_by='ticker')

# Extract 'Close' prices (since 'Adj Close' is missing)
close_prices = pd.DataFrame({ticker: data[ticker]['Close'] for ticker in stocks})

# Calculate daily returns
returns = close_prices.pct_change().dropna()

# Monte Carlo simulation parameters
num_portfolios = 10000
num_stocks = len(stocks)

results = np.zeros((3, num_portfolios))

# Run simulations
for i in range(num_portfolios):
    weights = np.random.random(num_stocks)
    weights /= np.sum(weights)

    port_return = np.sum(returns.mean() * weights) * 252
    port_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights)))
    sharpe_ratio = port_return / port_volatility

    results[0, i] = port_return
    results[1, i] = port_volatility
    results[2, i] = sharpe_ratio

# Plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(results[1, :], results[0, :], c=results[2, :], cmap='viridis', alpha=0.6)
plt.colorbar(scatter, label='Sharpe Ratio')
plt.xlabel('Volatility (Risk)')
plt.ylabel('Expected Return')
plt.title('Portfolio Optimization (using Close Prices)')
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed
